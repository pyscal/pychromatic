# %%
from pychromatic import Palette
from pychromatic import Multiplot

# %%
mpl = Multiplot(columns=4, rows=4, width=1500, palette="google")

# %%
mpl.axes[0,0].plot([1,2],[1,2], color=mpl.colors[3] )
mpl.axes[0,0].plot([1,2],[3,4])
mpl.axes[1,0].plot([1,2],[1,2])

mpl.show()
